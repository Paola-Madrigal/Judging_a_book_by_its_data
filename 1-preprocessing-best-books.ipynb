# %% [markdown]
# # Preprocessing Best Books Dataset
# 1. Dropping columns we don't need
# 2. Checking for duplicates
# 3. Converting to the correct data type
# 4. Handling missing values
# 5. Splitting multi-labeled columns
# 6. Removing typos and standardizing names
#
# Python 3.11.8

# %%
# GENERAL LIBRARIES
import numpy as np
import pandas as pd
import re
import kaggle_dataset # .py file
import difflib

# %%
print(' numpy:',np.__version__,'\n', 'pandas:',pd.__version__,'\n', 're:',re.__version__)
# Out:
#  numpy: 1.26.4
#  pandas: 2.1.4
#  re: 2.2.1

# %% [markdown]
# ### Import the data

# %%
datasets_path = kaggle_dataset.list_of_kaggle_datasets('https://www.kaggle.com/datasets/justinnguyen0x0x/best-books-of-the-21st-century-dataset')
raw_data = pd.read_csv(datasets_path[0], index_col = "id")
raw_data.head()
# Out:
# Note: You need to provide your Kaggle API credentials
# Skipping, found downloaded files in "./best-books-of-the-21st-century-dataset" (use force=True to force download)
# Files downloaded:
# best-books-of-the-21st-century-dataset/Best_Book_21st.csv
#                                                 title  \
# id
# 0                                         The Martian
# 1   Under the Banner of Heaven: A Story of Violent...
# 2                                   Cutting for Stone
# 3                         We Need to Talk About Kevin
# 4                The Immortal Life of Henrietta Lacks
#
#                           series              author  \
# id
# 0   \n        (The Martian #1)\n           Andy Weir
# 1                            NaN        Jon Krakauer
# 2                            NaN  Abraham   Verghese
# 3                            NaN      Lionel Shriver
# 4                            NaN      Rebecca Skloot
#
#                                             book_link  \
# id
# 0   https://www.goodreads.com/book/show/18007564-t...
# 1   https://www.goodreads.com/book/show/10847.Unde...
# 2   https://www.goodreads.com/book/show/3591262-cu...
# 3   https://www.goodreads.com/book/show/80660.We_N...
# 4   https://www.goodreads.com/book/show/6493208-th...
#
#                                                 genre      date_published  \
# id
# 0   Science Fiction,Fiction,Audiobook,Adventure,Sp...  February 11th 2014
# 1   Nonfiction,Religion,History,Crime,True Crime,M...                2004
# 2   Fiction,Historical,Historical Fiction,Cultural...   February 3rd 2009
# 3   Fiction,Contemporary,Thriller,Horror,Mystery,C...       July 3rd 2006
# 4   Nonfiction,Science,History,Biography,Health,Me...   February 2nd 2010
#
#                                   publisher  num_of_page     lang  \
# id
# 0                    Crown\n\n            ,        384.0  English
# 1            Pan MacMillan\n\n            ,        400.0  English
# 2          Alfred A. Knopf\n\n            ,        541.0  English
# 3         Harper Perennial\n\n            ,        400.0  English
# 4   Crown Publishing Group\n\n            ,        370.0  English
#
#    review_count rating_count  rate  \
# id
# 0        77,156      919,781  4.40
# 1        10,981      173,895  3.98
# 2        26,253      353,365  4.29
# 3        14,787      187,639  4.04
# 4        36,574      646,155  4.07
#
#                                                 award
# id
# 0   Kurd-Laßwitz-Preis for Bestes ausländisches We...
# 1   Colorado Book Award for General Nonfiction (2004)
# 2   PEN/Hemingway Foundation Award Nominee (2010),...
# 3                     Orange Prize for Fiction (2005)
# 4   Ambassador Book Award for American Studies (20...

# %% [markdown]
# ## 1. Dropping columns we don't need

# %%
# For each section, we will have a checkpoint, in case we need to go back in the code for modifications
df = raw_data.copy()
# We will drop the following columns:
# - book_link: This is not relevant information to our future analysis, since it's only informative
# - num_of_page: This is not relevant information to our future analysis, since it's only informative
# - review_count: There is no further data on reviews that can help us in our future analysis. It's only informative
df = df.drop(['book_link', 'num_of_page', 'review_count'], axis = 1)
df.head()
# Out:
#                                                 title  \
# id
# 0                                         The Martian
# 1   Under the Banner of Heaven: A Story of Violent...
# 2                                   Cutting for Stone
# 3                         We Need to Talk About Kevin
# 4                The Immortal Life of Henrietta Lacks
#
#                           series              author  \
# id
# 0   \n        (The Martian #1)\n           Andy Weir
# 1                            NaN        Jon Krakauer
# 2                            NaN  Abraham   Verghese
# 3                            NaN      Lionel Shriver
# 4                            NaN      Rebecca Skloot
#
#                                                 genre      date_published  \
# id
# 0   Science Fiction,Fiction,Audiobook,Adventure,Sp...  February 11th 2014
# 1   Nonfiction,Religion,History,Crime,True Crime,M...                2004
# 2   Fiction,Historical,Historical Fiction,Cultural...   February 3rd 2009
# 3   Fiction,Contemporary,Thriller,Horror,Mystery,C...       July 3rd 2006
# 4   Nonfiction,Science,History,Biography,Health,Me...   February 2nd 2010
#
#                                   publisher     lang rating_count  rate  \
# id
# 0                    Crown\n\n            ,  English      919,781  4.40
# 1            Pan MacMillan\n\n            ,  English      173,895  3.98
# 2          Alfred A. Knopf\n\n            ,  English      353,365  4.29
# 3         Harper Perennial\n\n            ,  English      187,639  4.04
# 4   Crown Publishing Group\n\n            ,  English      646,155  4.07
#
#                                                 award
# id
# 0   Kurd-Laßwitz-Preis for Bestes ausländisches We...
# 1   Colorado Book Award for General Nonfiction (2004)
# 2   PEN/Hemingway Foundation Award Nominee (2010),...
# 3                     Orange Prize for Fiction (2005)
# 4   Ambassador Book Award for American Studies (20...

# %% [markdown]
# ## 2. Checking for duplicates

# %%
df_duplicates_removed = df.copy()
# Retrieving a subset of the dataset with duplicated title and author
non_duplicates = df_duplicates_removed.drop_duplicates(subset = ['title','author']).index
df_duplicates_removed.loc[~df_duplicates_removed.index.isin(non_duplicates),:]
# Out:
#                                                   title  \
# id
# 900   I Am Malala: The Story of the Girl Who Stood U...
# 901                     Carnal: Somewhere Over 40 Winks
# 902   The Unlikely Pilgrimage of Harold Fry (Harold ...
# 903                                 Legend (Legend, #1)
# 904                                        Dreamcatcher
# ...                                                 ...
# 1816                                           Amazonia
# 1822          Together: AI and Human. On The Same Side.
# 4231                                   The God Delusion
# 8374                      The Gene: An Intimate History
# 8973                                    Norse Mythology
#
#                            series                           author  \
# id
# 900                           NaN  Malala Yousafzai,Christina Lamb
# 901                           NaN                     Rom LcO'Feer
# 902   \n        (Harold Fry #1)\n                     Rachel Joyce
# 903       \n        (Legend #1)\n                         Marie Lu
# 904                           NaN                     Stephen King
# ...                           ...                              ...
# 1816                          NaN                    James Rollins
# 1822                          NaN              Zoltan Andrejkovics
# 4231                          NaN                  Richard Dawkins
# 8374                          NaN             Siddhartha Mukherjee
# 8973                          NaN                      Neil Gaiman
#
#                                                   genre       date_published  \
# id
# 900   Nonfiction,Biography,Autobiography,Memoir,Femi...     October 8th 2013
# 901                     Contemporary,Psychology,Fiction  September 16th 2009
# 902   Fiction,Contemporary,Audiobook,Book Club,Adult...       July 24th 2012
# 903   Young Adult,Science Fiction,Dystopia,Science F...   November 29th 2011
# 904   Horror,Fiction,Science Fiction,Thriller,Fantas...     March 1st 2002 ,
# ...                                                 ...                  ...
# 1816  Thriller,Adventure,Fiction,Mystery,Action,Scie...       March 1st 2002
# 1822  Artificial Intelligence,Futurism,Pop Culture,G...  September 27th 2019
# 4231  Nonfiction,Religion,Science,Philosophy,Religio...        May 19th 2016
# 8374  Science,Nonfiction,History,Science,Biology,Hea...        May 17th 2016
# 8973  Fantasy,Fantasy,Mythology,Fiction,Audiobook,Sh...       March 6th 2018
#
#                                        publisher     lang rating_count  rate  \
# id
# 900   Little, Brown and Company\n\n            ,  English      489,281  4.12
# 901                    Lulu.com\n\n            ,  English        4,859  3.47
# 902                Random House\n\n            ,  English      162,236  3.91
# 903                              Putnam Juvenile  English      467,828  4.16
# 904                                          NaN  English      162,211  3.64
# ...                                          ...      ...          ...   ...
# 1816                                  Avon Books  English       32,815  4.13
# 1822                 Amazon Digital Services LLC  English           50  4.18
# 4231                 Black Swan\n\n            ,  English      253,935  3.89
# 8374                                    Scribner  English       40,139  4.32
# 8973     W. W. Norton & Company\n\n            ,  English      261,110  4.08
#
#                                                   award
# id
# 900   Lincoln Award Nominee (2017),Australian Book I...
# 901                                                 NaN
# 902   Booker Prize Nominee for Longlist (2012),Desmo...
# 903   Rhode Island Teen Book Award Nominee (2013),Mi...
# 904                                                 NaN
# ...                                                 ...
# 1816                                                NaN
# 1822                                                NaN
# 4231  British Book Award for The Author of the Year ...
# 8374  Royal Society Science Book Prize Nominee (2016...
# 8973  Tähtifantasia Award Nominee (2020),Goodreads C...
#
# [880 rows x 10 columns]

# %%
# Exploring a few of the duplicated values. Note: This line was run with different duplicated indices to get a general
# idea of what issues we can find in the dataset
index_to_check = 4231
df_duplicates_removed[(df_duplicates_removed['title'] == df_duplicates_removed.iloc[index_to_check, 0]) & 
                      (df_duplicates_removed['author'] == df_duplicates_removed.iloc[index_to_check, 2])]
# Out:
#                  title series           author  \
# id
# 768   The God Delusion    NaN  Richard Dawkins
# 1357  The God Delusion    NaN  Richard Dawkins
# 4231  The God Delusion    NaN  Richard Dawkins
#
#                                                   genre     date_published  \
# id
# 768   Nonfiction,Religion,Science,Philosophy,Religio...  October 18th 2006
# 1357  Nonfiction,Religion,Science,Philosophy,Religio...  October 18th 2006
# 4231  Nonfiction,Religion,Science,Philosophy,Religio...      May 19th 2016
#
#                                               publisher     lang rating_count  \
# id
# 768   Houghton Mifflin Co. (Boston/NY)\n\n            ,  English      253,491
# 1357  Houghton Mifflin Co. (Boston/NY)\n\n            ,  English      253,930
# 4231                        Black Swan\n\n            ,  English      253,935
#
#       rate                                              award
# id
# 768   3.89  British Book Award for The Author of the Year ...
# 1357  3.89  British Book Award for The Author of the Year ...
# 4231  3.89  British Book Award for The Author of the Year ...

# %%
# 1. Most of the duplicates seem to be updates of the same book and author
# 2. There are a few exceptions regarding the same book with different date_published and different publisher
#    which we will review individually
df_duplicates_removed = df_duplicates_removed.drop_duplicates(subset = ['title', 'author', 'date_published', 'publisher'],
                                          keep = 'last')

# %%
# Let's review the special cases we have left
non_duplicates = df_duplicates_removed.drop_duplicates(subset = ['title','author'], keep = False).index
df_duplicates_removed.loc[~df_duplicates_removed.index.isin(non_duplicates),:].sort_values(by = 'title')
# Out:
#                                       title                            series  \
# id
# 570   A Dog's Purpose (A Dog's Purpose, #1)  \n        (A Dog's Purpose #1)\n
# 1000  A Dog's Purpose (A Dog's Purpose, #1)  \n        (A Dog's Purpose #1)\n
# 6359                        Norse Mythology                               NaN
# 8973                        Norse Mythology                               NaN
# 62                  Saving CeeCee Honeycutt                               NaN
# 1065                Saving CeeCee Honeycutt                               NaN
# 1357                       The God Delusion                               NaN
# 4231                       The God Delusion                               NaN
#
#                         author  \
# id
# 570           W. Bruce Cameron
# 1000          W. Bruce Cameron
# 6359               Neil Gaiman
# 8973               Neil Gaiman
# 62    Beth Hoffman,Jenna Lamia
# 1065  Beth Hoffman,Jenna Lamia
# 1357           Richard Dawkins
# 4231           Richard Dawkins
#
#                                                   genre     date_published  \
# id
# 570   Fiction,Animals,Animals,Dogs,Contemporary,Adul...          July 2010
# 1000  Fiction,Animals,Animals,Dogs,Contemporary,Adul...          July 2010
# 6359  Fantasy,Fantasy,Mythology,Fiction,Audiobook,Sh...  February 7th 2017
# 8973  Fantasy,Fantasy,Mythology,Fiction,Audiobook,Sh...     March 6th 2018
# 62    Fiction,Historical,Historical Fiction,Womens F...  January 12th 2010
# 1065  Fiction,Historical,Historical Fiction,Womens F...  January 12th 2010
# 1357  Nonfiction,Religion,Science,Philosophy,Religio...  October 18th 2006
# 4231  Nonfiction,Religion,Science,Philosophy,Religio...      May 19th 2016
#
#                                               publisher     lang rating_count  \
# id
# 570                                         Forge Books  English      121,815
# 1000                                              Forge  English      122,008
# 6359                             W. W. Norton & Company  English      261,139
# 8973            W. W. Norton & Company\n\n            ,  English      261,110
# 62                       Penguin Audio\n\n            ,  English       82,797
# 1065                                      Penguin Audio  English       82,868
# 1357  Houghton Mifflin Co. (Boston/NY)\n\n            ,  English      253,930
# 4231                        Black Swan\n\n            ,  English      253,935
#
#       rate                                              award
# id
# 570   4.33  Goodreads Choice Award Nominee for Fiction (20...
# 1000  4.33  Goodreads Choice Award Nominee for Fiction (20...
# 6359  4.08  Tähtifantasia Award Nominee (2020),Goodreads C...
# 8973  4.08  Tähtifantasia Award Nominee (2020),Goodreads C...
# 62    3.92  Goodreads Choice Award Nominee for Fiction and...
# 1065  3.92  Goodreads Choice Award Nominee for Fiction and...
# 1357  3.89  British Book Award for The Author of the Year ...
# 4231  3.89  British Book Award for The Author of the Year ...

# %%
# There are four special duplicate cases left:
# 1. Two of them look like typos in the publisher, so we can keep the most updated review history (last record)
# 2. The other two have different publish date. This may be because the publisher published a new version of the same book
#    (in the first case), and because there was a publisher that published the book first (second case). In both cases, we
#    want to keep the first date that the book was published (first record)
df_duplicates_removed = df_duplicates_removed.drop_duplicates(subset = ['title', 'author', 'date_published'],
                                          keep = 'last') # First issue
df_duplicates_removed = df_duplicates_removed.drop_duplicates(subset = ['title', 'author'], keep = 'first') # Second issue

# %%
# Reseting the indexes
df_duplicates_removed = df_duplicates_removed.reset_index(drop = True)
# Let's verify all duplicates for title and author were removed
df_duplicates_removed.duplicated(subset = ['title', 'author'], keep = False).sum()
# Out:
# 0

# %% [markdown]
# ## 3. Converting to the correct data type

# %%
df_correct_dtype = df_duplicates_removed.copy()
# Let's check what is the date type of each column
df_correct_dtype.dtypes
# Out:
# title              object
# series             object
# author             object
# genre              object
# date_published     object
# publisher          object
# lang               object
# rating_count       object
# rate              float64
# award              object
# dtype: object

# %% [markdown]
# **String columns: 'title', 'author', 'genre', 'publisher', 'lang'**

# %%
# First, we convert all the string columns to a string data type
columns_to_convert = ['title', 'author', 'genre', 'publisher', 'lang']
df_correct_dtype[columns_to_convert] = df_correct_dtype[columns_to_convert].astype(dtype = 'string')
df_correct_dtype.dtypes
# Out:
# title             string[python]
# series                    object
# author            string[python]
# genre             string[python]
# date_published            object
# publisher         string[python]
# lang              string[python]
# rating_count              object
# rate                     float64
# award                     object
# dtype: object

# %% [markdown]
# **Integer columns: 'rating_count', 'award'**

# %%
# Columns 'rating_count', 'award' should be integer columns
# 1. 'award' must be transformed to numbers
# Mapping books with no awards
no_awards = df_correct_dtype['award'].isnull()
# Iterating through the awards to count them
for row in range(df_correct_dtype.shape[0]):
    if no_awards[row] == True:
        df_correct_dtype.loc[row, 'award'] = 0
    else:
        df_correct_dtype.loc[row, 'award'] = len(df_correct_dtype.loc[row, 'award'].split(","))

# %%
# 2. We must remove "," from 'rating_count'
for row in range(df_correct_dtype.shape[0]):
    if type(df_correct_dtype.loc[row, 'rating_count']) == str:
        df_correct_dtype.loc[row, 'rating_count'] = df_correct_dtype.loc[row, 'rating_count'].replace(",", "")
            
# Also, NaN values mean there are no ratings
df_correct_dtype.loc[:, ['rating_count']] = df_correct_dtype.loc[:, ['rating_count']].fillna(0)

# %%
# Transform the columns to integer type
columns_to_convert = ['rating_count', 'award']
df_correct_dtype[columns_to_convert] = df_correct_dtype[columns_to_convert].astype(dtype = 'int32')
df_correct_dtype.dtypes
# Out:
# title             string[python]
# series                    object
# author            string[python]
# genre             string[python]
# date_published            object
# publisher         string[python]
# lang              string[python]
# rating_count               int32
# rate                     float64
# award                      int32
# dtype: object

# %% [markdown]
# **Boolean columns: 'series'**

# %%
# All values from 'series' that are null means they don't belong to a series of books. Therefore, they must be set to 0
df_correct_dtype.loc[:, 'series'] = df_correct_dtype.loc[:, 'series'].fillna(0)
# All the others belong to a series of books, and must be set to 1
for row in range(df_correct_dtype.shape[0]):
    if df_correct_dtype.loc[row, 'series'] != 0:
        df_correct_dtype.loc[row, 'series'] = 1

# %%
# We convert the 'series' column to boolean
columns_to_convert = ['series']
df_correct_dtype[columns_to_convert] = df_correct_dtype[columns_to_convert].astype(dtype = 'bool')
df_correct_dtype.dtypes
# Out:
# title             string[python]
# series                      bool
# author            string[python]
# genre             string[python]
# date_published            object
# publisher         string[python]
# lang              string[python]
# rating_count               int32
# rate                     float64
# award                      int32
# dtype: object

# %% [markdown]
# **Float columns: date_published**

# %%
# Since for some dates we have the full date, for some we have month and year, and for some only the year, we will keep
# only the year in all columns. Also, when we don't have a date available we cannot transform it to 0. It will need to
# stay as a null value. Due to this, we cannot transform the data type to integer, and we will keep it as floating
for row in range(df_correct_dtype.shape[0]):
    if type(df_correct_dtype.loc[row, 'date_published']) == str:
        if re.findall('[1-9][0-9]{3}', df_correct_dtype.loc[row, 'date_published']):
            df_correct_dtype.loc[row, 'date_published'] = re.findall('[1-9][0-9]{3}', df_correct_dtype.loc[row, 'date_published'])[0]
        else:
            df_correct_dtype.loc[row, 'date_published'] = np.NaN

# %%
# We transform the 'date_published' column to float:
columns_to_convert = 'date_published'
df_correct_dtype[columns_to_convert] = df_correct_dtype[columns_to_convert].astype(dtype = 'float')
df_correct_dtype.dtypes
# Out:
# title             string[python]
# series                      bool
# author            string[python]
# genre             string[python]
# date_published           float64
# publisher         string[python]
# lang              string[python]
# rating_count               int32
# rate                     float64
# award                      int32
# dtype: object

# %% [markdown]
# ## 4. Handling missing values

# %%
df_nans_removed = df_correct_dtype.copy()
# We will first take a look at the total of null values per columns. We will handle each column depending on what we want
df_nans_removed.isnull().sum()
# Out:
# title               0
# series              0
# author             15
# genre             979
# date_published    145
# publisher         380
# lang              507
# rating_count        0
# rate               15
# award               0
# dtype: int64

# %% [markdown]
# **Missing values: 'rating_count', 'rate'**

# %%
# We will start with the missing values for our target variables, since we need these values for our analysis
df_nans_removed[df_nans_removed[['rating_count', 'rate']].isnull().any(axis = 1)]
# Out:
#                                                 title  series author genre  \
# 0                                     The Known World   False   <NA>  <NA>
# 1                                            Coraline   False   <NA>  <NA>
# 2                     Graceling (Graceling Realm, #1)   False   <NA>  <NA>
# 3                                     Year of Wonders   False   <NA>  <NA>
# 4   The Last Olympian (Percy Jackson and the Olymp...   False   <NA>  <NA>
# 5                                             Freedom   False   <NA>  <NA>
# 6      A Feast for Crows (A Song of Ice and Fire, #4)   False   <NA>  <NA>
# 7                                       The Goldfinch   False   <NA>  <NA>
# 8   The Sea of Monsters (Percy Jackson and the Oly...   False   <NA>  <NA>
# 9               The Maze Runner (The Maze Runner, #1)   False   <NA>  <NA>
# 10  The Millennium Trilogy (Millennium Trilogy, #1-3)   False   <NA>  <NA>
# 11                       The Elegance of the Hedgehog   False   <NA>  <NA>
# 12                 Pattern Recognition (Blue Ant, #1)   False   <NA>  <NA>
# 13     World War Z: An Oral History of the Zombie War   False   <NA>  <NA>
# 14                               Thirteen Reasons Why   False   <NA>  <NA>
#
#     date_published publisher  lang  rating_count  rate  award
# 0              NaN      <NA>  <NA>             0   NaN      0
# 1              NaN      <NA>  <NA>             0   NaN      0
# 2              NaN      <NA>  <NA>             0   NaN      0
# 3              NaN      <NA>  <NA>             0   NaN      0
# 4              NaN      <NA>  <NA>             0   NaN      0
# 5              NaN      <NA>  <NA>             0   NaN      0
# 6              NaN      <NA>  <NA>             0   NaN      0
# 7              NaN      <NA>  <NA>             0   NaN      0
# 8              NaN      <NA>  <NA>             0   NaN      0
# 9              NaN      <NA>  <NA>             0   NaN      0
# 10             NaN      <NA>  <NA>             0   NaN      0
# 11             NaN      <NA>  <NA>             0   NaN      0
# 12             NaN      <NA>  <NA>             0   NaN      0
# 13             NaN      <NA>  <NA>             0   NaN      0
# 14             NaN      <NA>  <NA>             0   NaN      0

# %%
# We can see that the only value we have is the title of the book. Therefore, we can remove these records
df_nans_removed = df_nans_removed.dropna(subset = ['rating_count', 'rate'])
# We check how our null values table looks now
df_nans_removed.isnull().sum()
# Out:
# title               0
# series              0
# author              0
# genre             964
# date_published    130
# publisher         365
# lang              492
# rating_count        0
# rate                0
# award               0
# dtype: int64

# %%
# Also, we can deduce that if the rating_count is 0, then no one has evaluated the book, and the rate becomes irrelevant
df_nans_removed[df_nans_removed['rating_count'] == 0]
# Out:
#                                                   title  series       author  \
# 3214                           STORY OF AN INDIAN WOMAN   False  Anantaroopa
# 3494  Don’t Monkey Around When It Comes To Saving Mo...   False     D. Terry
# 3716  You Win Even When You Lose: 50 Secrets And Tip...   False     D. Terry
# 3959  Pretty Near Perfect: : 40 Skin Care Tips To He...   False     D. Terry
# 4247  Six-Pack Abs: A Quick, Concise Guide To Obtain...   False     D. Terry
# 7630                Grave Results Book Two: Blood Rites   False    Dana Reed
#
#      genre  date_published                      publisher     lang  \
# 3214  <NA>          2015.0                           <NA>  English
# 3494  <NA>          2013.0                      BookTango  English
# 3716  <NA>          2013.0                      BookTango  English
# 3959  <NA>          2013.0                      BookTango  English
# 4247  <NA>          2013.0                      BookTango  English
# 7630  <NA>          2005.0  PublishAmerica
#
#             ,  English
#
#       rating_count  rate  award
# 3214             0   0.0      0
# 3494             0   0.0      0
# 3716             0   0.0      0
# 3959             0   0.0      0
# 4247             0   0.0      0
# 7630             0   0.0      0

# %%
# Therefore, we will consider these values as "null" and remove them from the dataset
df_nans_removed = df_nans_removed[df_nans_removed['rating_count'] != 0].reset_index(drop = True)

# %% [markdown]
# **Missing values: 'genre', 'publisher', 'lang'**

# %%
# For the missing values of 'genre', 'publisher' and 'lang', we can change the null values to Unknown
unknown_values = df_nans_removed.loc[:,['genre', 'publisher', 'lang']].fillna('Unknown')
df_nans_removed.loc[:, ['genre', 'publisher', 'lang']] = unknown_values
df_nans_removed.reset_index(drop = True, inplace = True)
# We check how our null values table looks now. We should only have null values in 'date_published'
# The approach we will take is to replace the date_published with the most common value.
# This will be done during the Data Analysis
df_nans_removed.isnull().sum()
# Out:
# title               0
# series              0
# author              0
# genre               0
# date_published    130
# publisher           0
# lang                0
# rating_count        0
# rate                0
# award               0
# dtype: int64

# %% [markdown]
# ## 5. Splitting multi-labeled columns

# %%
df_label_splitted = df_nans_removed.copy()

# %%
# We will keep only the first genre that appears for each book (the main one)
# Since we already dealt with the missing values, we can expect to have at least one value
for row in range(len(df_label_splitted)):
    genres = df_label_splitted.loc[row,'genre'].split(",")[0:2]
    df_label_splitted.loc[row, 'genre'] = genres[0]
    # NOTE: If we wanted to include two genres, we would have to generate a new record for each book.
    # In that case, we can use the code below within the for loop
    #try:
    #    new_row = df_label_splitted.loc[row, :].copy()
    #    new_row.loc['genre'] = genres[1]
    #    df_label_splitted = df_label_splitted.append(new_row, ignore_index = True)
    #except:
    #    pass

# %%
# We will keep only the first author that appears for each book (the main one)
# Since we already dealt with the missing values, we can expect to have at least one value
for row in range(len(df_label_splitted)):
    authors = df_label_splitted.loc[row,'author'].split(",")[0:2]
    df_label_splitted.loc[row, 'author'] = authors[0]
    # NOTE: If we wanted to include two authors, we would have to generate a new record for each book.
    # In that case, we can use the code below within the for loop
    #try:
    #    new_row = df_label_splitted.loc[row, :].copy()
    #    new_row.loc['author'] = genres[1]
    #    df_label_splitted = df_label_splitted.append(new_row, ignore_index = True)
    #except:
    #    pass

# %%
df_label_splitted
# Out:
#                                                   title  series  \
# 0               Fantastic Beasts and Where to Find Them    True
# 1                                         Houdini Heart   False
# 2                   An Echo in the Bone (Outlander, #7)    True
# 3                                           Three Junes   False
# 4                   The Dark Tower (The Dark Tower, #7)    True
# ...                                                 ...     ...
# 9112            Edge of Passion (Stealth Guardians, #1)    True
# 9113  Tales from a Not-So-Popular Party Girl (Dork D...    True
# 9114                                            Bottoms   False
# 9115                                  The Wedding Dress   False
# 9116  The Immortal Hunter (Argeneau #11; Rogue Hunte...    True
#
#                     author       genre  date_published  \
# 0           Newt Scamander     Fantasy          2001.0
# 1            Ki Longfellow      Horror          2011.0
# 2           Diana Gabaldon  Historical          2010.0
# 3              Julia Glass     Fiction          2003.0
# 4             Stephen King     Fantasy          2006.0
# ...                    ...         ...             ...
# 9112           Tina Folsom     Fantasy          2012.0
# 9113  Rachel Renée Russell   Childrens          2010.0
# 9114       Tanja Kirschner     Unknown          2005.0
# 9115        Gary E. Parker     Unknown          2002.0
# 9116          Lynsay Sands     Romance          2009.0
#
#                                   publisher     lang  rating_count  rate  \
# 0     Arthur A. Levine Books
#
#             ,  English        372109  3.96
# 1                                 Eio Books  English         10409  3.75
# 2                      Orion
#
#             ,  English        133940  4.40
# 3                     Anchor
#
#             ,  English         45789  3.56
# 4               Pocket Books
#
#             ,  English        162749  4.23
# ...                                     ...      ...           ...   ...
# 9112                                Unknown  English          1011  4.01
# 9113                                Aladdin  English         54285  4.24
# 9114              NorthSouth
#
#             ,  English            11  3.55
# 9115                  Victor
#
#             ,  English            23  3.61
# 9116                                   Avon  English         14498  4.22
#
#       award
# 0         0
# 1         0
# 2         2
# 3         1
# 4         1
# ...     ...
# 9112      0
# 9113      0
# 9114      0
# 9115      0
# 9116      0
#
# [9117 rows x 10 columns]

# %% [markdown]
# ## 6. Removing typos and standardizing names

# %%
df_typos_removed = df_label_splitted.copy()

# %% [markdown]
# **Typos: genre**

# %%
# Verify genres don't have similar values
genres = df_typos_removed['genre'].unique()
for i in range(len(genres)):
    close_matches = difflib.get_close_matches(genres[i],genres[i+1:], n = 1, cutoff = 0.7)
    if len(close_matches) != 0:
        print(genres[i],':', close_matches)

# NOTE: No typos were found. Also, genres cannot be so easily standardize, even if they are very similar.
# For example, a Historical book (perhaps a historical novel based on a historical fact) is different to a History book
# Out:
# Historical : ['History']
# Fiction : ['Fan Fiction']
# Science Fiction : ['Science Fiction Fantasy']
# Womens Fiction : ['Fan Fiction']
# Autobiography : ['Biography']
# Christian : ['Christianity']
# Cultural : ['Culture']
# Christian Fiction : ['Christianity']
# Psychology : ['Mythology']
# Health : ['Death']
# Eastern Africa : ['Northern Africa']
# Literature : ['Asian Literature']
# European Literature : ['Asian Literature']

# %% [markdown]
# **Typos: author**

# %%
# Verify authors don't have similar values
authors = df_typos_removed['author'].unique()
for i in range(len(authors)):
    close_matches = difflib.get_close_matches(authors[i],authors[i+1:], cutoff = 0.92)
    if len(close_matches) != 0:
        print(authors[i],':', close_matches)
# Out:
# Matthew Quick : ['Matthew Quirk']
# Michelle Moran : ['Michelle  Morgan']
# Steven Erikson : ['Steve Erickson']
# Richard  Holmes : ['Richard   Holmes']
# Elizabeth Berg : ['Elizabeth Bear']
# Emmanuel M. Kolini : ['Emmanual M. Kolini']
# RamG Vallath : ['Ram G. Vallath']
# Victor G. LaVanWay : ['Victor G. La Van Way']
# David Abram : ['David Abrams']
# Justin Richardson : ['Justin Richards']
# Alycia  Ripley : ['Alycia Ripley']
# Richard Zimler : ['Richard Bimler']

# %%
# These are the only authors with real typos (the others were verified to be different authors):
    # Richard Holmes
    # Emmanuel M. Kolini
    # Ram G. Vallath
    # Victor G. La Van Way
    # Alycia Ripley
# Since it's possible for the dataset to be updated (and have new errors), they will be fixed completely manually
df_typos_removed.loc[(df_typos_removed['author'] == 'Richard  Holmes') | (df_typos_removed['author'] == 'Richard   Holmes'),'author'] = 'Richard Holmes'
df_typos_removed.loc[df_typos_removed['author'] == 'Emmanual M. Kolini','author'] = 'Emmanuel M. Kolini'
df_typos_removed.loc[df_typos_removed['author'] == 'RamG Vallath','author'] = 'Ram G. Vallath'
df_typos_removed.loc[df_typos_removed['author'] == 'Victor G. LaVanWay','author'] = 'Victor G. La Van Way'
df_typos_removed.loc[df_typos_removed['author'] == 'Alycia  Ripley','author'] = 'Alycia Ripley'

# %% [markdown]
# **Typos: publisher**

# %%
# We will remove new lines, commas and front and back whitespaces from the publisher
print('BEFORE:\n',df_typos_removed['publisher'].head())
df_typos_removed['publisher'] = df_typos_removed['publisher'].str.replace('\n','').str.replace(',','').str.strip()
print('\nAFTER:\n',df_typos_removed['publisher'].head())
# Out:
# BEFORE:
#  0    Arthur A. Levine Books
#
#             ,
# 1                                Eio Books
# 2                     Orion
#
#             ,
# 3                    Anchor
#
#             ,
# 4              Pocket Books
#
#             ,
# Name: publisher, dtype: string
#
# AFTER:
#  0    Arthur A. Levine Books
# 1                 Eio Books
# 2                     Orion
# 3                    Anchor
# 4              Pocket Books
# Name: publisher, dtype: string

# %%
# Verify publishers don't have similar values (1st verification)
publishers = df_typos_removed['publisher'].unique()
for i in range(len(publishers)):
    close_matches = difflib.get_close_matches(publishers[i],publishers[i+1:], cutoff=0.9)
    if len(close_matches) != 0:
        print(publishers[i],':', close_matches)
# Out:
# Little Brown and Company : ['Little Brown And Company', 'Little Brown & Company']
# W. W. Norton  Company : ['W. W. Norton & Company', 'W.W. Norton & Company']
# Simon & Schuster : ['Simon  Schuster', 'Simon Schuster', 'Simon & Schuster UK']
# Bloomsbury Publishing PLC : ['Bloomsbury Publishing Plc', 'Bloomsbury Publishing']
# Farrar Straus and Giroux : ['Farrar Straus Giroux', 'Farrar Straus and Giroux (NY)']
# G.P. Putnam's Sons : ["G. P. Putnam's Sons", 'G.P. Putnam’s Sons']
# Farrar Straus and Giroux (NY) : ['Farrar Straus and Giroux (BYR)', 'Farrar Straus and Giroux (Byr)']
# Bloomsbury USA Childrens : ["Bloomsbury USA Children's", 'Bloomsbury Childrens']
# Simon & Schuster Books for Young Readers : ['Simon  Schuster Books for Young Readers', 'Simon & Schuster Books For Young Readers', 'Simon Schuster Books for Young Readers']
# St. Martin's Press : ['St. Martins Press', "St Martin's Press", 'St. Martin’s Press']
# Disney-Hyperion : ['Disney/Hyperion', 'Disney Hyperion']
# Scholastic : ['scholastic']
# Simon  Schuster Books for Young Readers : ['Simon Schuster Books for Young Readers', 'Simon & Schuster Books For Young Readers']
# HarperTeen : ['Harper Teen']
# Createspace : ['CreateSpace']
# HarperCollins : ['Harper Collins', 'Harpercollins']
# CreateSpace Independent Publishing Platform : ['Create Space Independent  Publishing Platform', 'Createspace Independent Publishing Platform', 'Createspace Indpendent Publishing Platform']
# Henry Holt & Company : ['Henry Holt Company', 'Henry Holt and Company']
# CreateSpace : ['Create Space']
# HarperCollins Publishers : ['Harper Collins Publishers', 'HarperCollins Publishers Ltd', 'HarperCollins Publishers Inc.']
# Little Brown & Company : ['Little Brown And Company']
# Bloomsbury Children's Books : ['Bloomsbury Children’s Books']
# Viking's Children's Books : ["Viking Children's Books"]
# Disney-Hyperion Books : ['Disney Hyperion Books', 'Disney ● Hyperion Books']
# Del Rey/Ballantine Books : ['Del Rey / Ballantine Books']
# Createspace Independent Publishing Platform : ['Createspace Indpendent Publishing Platform', 'Create Space Independent  Publishing Platform']
# Zola Books : ['Zoland Books']
# Disney Hyperion Books : ['Disney ● Hyperion Books']
# Random House Audio Publishing Group : ['Random House Publishing Group']
# HarperTrophy : ['Harper Trophy']
# Simon  Schuster : ['Simon Schuster', 'Simon and Schuster', 'Simon  Schuster UK']
# Orion Children's Books : ['Orion Childrens Books']
# The Random House Publishing Group : ['Random House Publishing Group']
# Self Published : ['Self-Published']
# Amazon Digital Services : ['Amazon Digital Services LLC', 'Amazon Digital Services Inc.']
# Tate Publishing & Enterprises : ['Tate Publishing & Enterprises LLC']
# AmazonCrossing : ['Amazon Crossing']
# Walker Books Ltd. : ['Walker Books Ltd']
# St. Martins Press : ['St. Martin’s Press', "St Martin's Press"]
# HarperCollins Children's Books : ["HarperCollins Children's Book's", "Harper Collins Children's Books", 'HarperCollins Children’s Books']
# G.P. Putnam's Sons Books for Young Readers : ['G.P. Putnam’s Sons Books for Young Readers']
# Srishti Publishers & Distributers : ['Srishti Publishers & Distributors', 'Srishti Publishers and Distributors']
# Canongate Us : ['Canongate UK']
# Entangled Teen : ['Entangled: Teen']
# Allen & Ulwin : ['Allen & Unwin']
# HarperCollins Children's Book's : ["Harper Collins Children's Books", 'HarperCollins Children’s Books', "HarperCollinsChildren'sBooks"]
# Pan MacMillan : ['Pan Macmillan']
# Crown Publishing Group : ['Orion Publishing Group']
# Bloomsbury USA Children's : ["Bloomsbury Children's"]
# Bloomsbury Publishing : ['Bloomsbury Publishing Plc']
# Authorhouse : ['AuthorHouse']
# HarperCollins Publishers Ltd : ['Harper Collins Publishers']
# Chatto  Windus : ['Chatto & Windus']
# Penguin Group (USA) : ['Penguin Group USA']
# Balzer + Bray : ['Balzer & Bray']
# Bloomsbury Childrens : ['Bloomsbury Children’s', "Bloomsbury Children's"]
# Harper Voyager : ['HarperVoyager']
# G.P. Putnam’s Sons : ["G. P. Putnam's Sons"]
# Self-published : ['Self-Published']
# Booksurge Publishing : ['BookSurge Publishing']
# Disney Hyperion : ['Disney/Hyperion']
# W.W. Norton & Company : ['W. W. Norton & Company']
# EgmontUSA : ['Egmont USA']
# Artof4Elements : ['Artof4elements', 'Art of 4 Elements']
# Independently published : ['Independently Published']
# Seventh Star Press : ['Seventh Star Press LLC']
# Smashwords : ['Smashword']
# RPG Publishing : ['VPG Publishing']
# Forsaken Press via Createspace : ['Forsaken Press (via Createspace)', 'Forsaken Pres Via Createspace', 'Forsaken Press (via createspace)']
# Ellora's Cave Publishing Inc. : ["Ellora's Cave Publishing"]
# Beau Coup Publishing llc : ['Beau Coup Publishing']
# St. Martin’s Press : ["St Martin's Press"]
# Harper Collins Children's : ["HarperCollins Children's"]
# Faber  Faber : ['Faber & Faber']
# House of Anansi Press : ['House of Anansi Press Inc']
# Random House (NY) : ['Random House (NYC)']
# Amazon Kindle : ['Amazon kindle']
# PanMacmillan Australia : ['Pan Macmillan Australia']
# PanMacmillan : ['Pan Macmillan', 'Pan Macmillian']
# Allen & Unwin : ['Allen  Unwin']
# MacMillan Audio : ['Macmillan Audio']
# Forsaken Press (via createspace) : ['Forsaken Press (via Createspace)', 'Forsaken Press (via CreateSpace)']
# Forsaken Press (via CreateSpace) : ['Forsaken Press (via Createspace)']
# Forsaken Press (via Createspace) : ['Forsaken Pres Via Createspace']
# Random House Books for Young Readers : ['Random House for Young Readers']
# Select Books : ['SelectBooks']
# RoutledgeFalmer : ['Routledge Falmer']
# Publish America : ['PublishAmerica']
# Tyndale House Publishers : ['Tyndale House Publisher', 'Tyndale House Publishers Inc.']
# Adamantine Publishing House : ['Adamantine PublishingHouse']
# Olive Branch Press : ['Olive Branch Pr']
# HarperCollins Children’s Books : ['HarperCollinsChildren’sBooks', "Harper Collins Children's Books", "HarperCollinsChildren'sBooks"]
# HarperCollinsChildren'sBooks : ['HarperCollinsChildren’sBooks', "Harper Collins Children's Books"]
# Harper Collins Children's Books : ['HarperCollinsChildren’sBooks']
# Metropolitan Books/Henry Holt (NY) : ['Metropolitan Books/Henry Holt & Co. (NY)', 'Metropolitan Books/Henry Holt & Co. (NYC)']
# Simon Schuster Books for Young Readers : ['Simon & Schuster Books For Young Readers']
# World Wrestling Entertainment Books : ['World Wrestling Entertainment']
# HarperPress : ['Harper Press']
# Rupa & Co : ['Rupa & Co.']
# Pan Macmillian : ['Pan Macmillan']
# Big Finish Productions : ['Big Finish Productions Ltd']
# MacAdam/Cage : ['MacAdam Cage']
# Ilyan Kei Lavanway : ['Ilyan Kei lavanway']
# John Murray Publishers : ['John Murray Publisher']
# Oxford University Press USA : ['Oxford University Press']
# Whiteley Publishing : ['Whiteley Publishing Ltd']
# David C Cook : ['David C. Cook']
# The Friday Project : ['The Friday Pjoject']
# دار العربية للعلوم ناشرون : ['الدار العربية للعلوم ناشرون']
# Linlithglow Press : ['Linlithgow Press']
# Dagda Publishing Ltd. : ['Dagda Publishing Ltd']
# Laurențiu M. Badea : ['Laurențiu Badea']
# WildBlue Press : ['Wild Blue Press']
# Crush Publishing Inc : ['Crush Publishing Ink']
# Harlequin Enterprises Limited : ['Harlequin Enterprises Ltd.']
# Srishti Publishers & Distributors : ['Srishti Publishers and Distributors']
# Createspace Indpendent Publishing Platform : ['Create Space Independent  Publishing Platform']
# Orion Publishing : ['Orion Publishing Co']
# Farrar Straus and Giroux (Byr) : ['Farrar Straus and Giroux (BYR)']
# Amulet Books : ['Amulet books']
# Henry Holt and Company : ['Henry Holt Company']
# F Otieno : ['F. Otieno']
# HarperBusiness : ['Harper Business']
# WaterBrook Press : ['Waterbrook Press']
# Simon & Schuster UK : ['Simon  Schuster UK']
# HarperCollins UK : ['HarperCollins (UK)']
# Simon and Schuster Audio : ['Simon  Schuster Audio']
# Stanford University Press : ['Samford University Press']
# Macmillan Children's Books : ["MacMillan Children's Books"]
# HighBridge Audio : ['Highbridge Audio']
# Douglas  McIntyre : ['Douglas & McIntyre']
# Bloomsbury Children’s : ["Bloomsbury Children's"]
# Metropolitan Books/Henry Holt & Co. (NY) : ['Metropolitan Books/Henry Holt & Co. (NYC)']
# Orion Childrens : ["Orion Children's"]
# Dreamspinner Press : ['Dreamspinner Press LLC']
# University of North Carolina Press : ['University of South Carolina Press']
# Thames & Hudson : ['Thames  Hudson']
# International Islamic Publishing House - IIPH : ['International Islamic Publishing House (IIPH)']
# HarperSport : ['Harper Sport']
# Polity Press : ['Policy Press']
# Warner : ['Warne']
# Usborne Publishing Ltd : ['Usborne Publishing']
# AudioGo Ltd : ['AudioGO Ltd']

# %%
# At a first glance, there are several issues that can be standardize in order to have a more standard publisher
# NOTE: A new column will be created, since we only need unique values for the analysis and we will be able to go back to the original publisher name
# 1. Lower case all of the publishers
df_typos_removed['publisher_clean'] = df_typos_removed['publisher'].str.lower()
# 2. Remove & and "and"
df_typos_removed['publisher_clean'] = df_typos_removed['publisher_clean'].str.replace(' & ',' ').str.replace(' and ',' ')
# 3. Remove special characters (letters only)
df_typos_removed['publisher_clean'] = df_typos_removed['publisher_clean'].str.replace('[^a-z\s]+',' ',regex = True).str.strip()
# 4. Remove non-neceessary abbreviations at the middle and at end of the name
df_typos_removed['publisher_clean'] = df_typos_removed['publisher_clean'].str.replace(' co ',' ').str.replace(' ltd ',' ').str.replace(' inc ',' ')
strings_to_remove = [' co$',' ltd$',' inc$',' llc$',' plc$',' ya$',' ink$']
for remove in strings_to_remove:
    df_typos_removed['publisher_clean'] = df_typos_removed['publisher_clean'].str.replace(remove, '', regex = True).str.strip()
# 5. Remove countries/cities at the middle and at the end of the name
df_typos_removed['publisher_clean'] = df_typos_removed['publisher_clean'].str.replace(' usa ',' ')
places_to_remove = [' uk$',' us$',' usa$',' ny$',' nyc$',' byr$',' gb$',' au$',' ma$',' az$']
for remove in places_to_remove:
    df_typos_removed['publisher_clean'] = df_typos_removed['publisher_clean'].str.replace(remove, '', regex = True).str.strip()
# 6. Remove all whitespaces
df_typos_removed['publisher_clean'] = df_typos_removed['publisher_clean'].str.replace(' ','')

# %%
# Verify publishers don't have similar values (2nd verification)
publishers = df_typos_removed['publisher_clean'].unique()
# NOTE: There are many different publishers that end with "publishing", so we will remove them from the checklist
publishers = list(filter(lambda x: not x.endswith('publishing'),publishers))
list_of_corrections = []
for i in range(len(publishers)):
    close_matches = difflib.get_close_matches(publishers[i],publishers[i+1:], cutoff=0.86)
    if len(close_matches) != 0:
        list_of_corrections.append([publishers[i],close_matches])
        print(publishers[i],':', close_matches)
# Out:
# eiobooks : ['keibooks']
# simonschuster : ['simonschusterbfyr']
# margaretkmcelderrybooks : ['margaretkmcelderry']
# penguinpress : ['thepenguinpress']
# bloomsburychildrens : ['bloomsburychildrensbooks']
# alfredaknopf : ['alfredknopf']
# stmartinspress : ['stmartinspresspl']
# delacortepress : ['delacortepr']
# houghtonmifflinharcourt : ['houghtonmifflinharcourtboston']
# thechickenhouse : ['chickenhouse']
# torbooks : ['orbooks']
# duttonbooksforyoungreaders : ['crownbooksforyoungreaders']
# harpercollins : ['harpercoll', 'harpercollinsecco', 'eccoharpercollins']
# canongateus : ['canongate']
# createspaceindependentpublishingplatform : ['createspaceindpendentpublishingplatform']
# marinerbooks : ['warnerbooks']
# littlebrownbooksforyoungreaders : ['littlebrowncompanybooksforyoungreaders']
# randomhouseaudio : ['randomhouseaudiobooks']
# emuhousepublications : ['dreamhousepublication']
# bloomsburychildrensbooks : ['bloomsburyusachildrensbooks']
# penguingroup : ['thepenguingroup', 'penguingroupdaw']
# hyperionbookch : ['hyperionbooks']
# vikingschildrensbooks : ['vikingchildrensbooks']
# amyeinhornputnam : ['amyeinhornbooksputnam']
# zolabooks : ['zolandbooks']
# randomhouseaudiopublishinggroup : ['randomhousepublishinggroup', 'therandomhousepublishinggroup']
# atheneumbooksforyoungreaders : ['hmhbooksforyoungreaders']
# therandomhousepublishinggroup : ['randomhousepublishinggroup']
# selfpublished : ['selfpublishedonao']
# houghtonmifflinboston : ['houghtonmifflinbooks']
# harpercollinsharpertorch : ['harpercollinsharper']
# harpercollinschildrensbooks : ['harpercollinschildrens']
# srishtipublishersdistributers : ['srishtipublishersdistributors']
# penguinaustralia : ['penguingroupaustralia']
# allenulwin : ['allenunwin']
# panmacmillan : ['panmacmillian']
# knopfbooksforyoungreaders : ['alfredaknopfbooksforyoungreaders', 'vikingbooksforyoungreaders']
# smashwords : ['smashword', 'smashwordscom']
# forsakenpressviacreatespace : ['forsakenpresviacreatespace']
# listeninglibraryaudio : ['listeninglibrary']
# greenwillowbooks : ['greenhillbooks']
# owlbooks : ['howbooks']
# randomhousebooksforyoungreaders : ['randomhouseforyoungreaders', 'randomhousedelacortebooksforyoungreaders']
# salmonpress : ['almondpress']
# tyndalehousepublishers : ['tyndalehousepublisher']
# olivebranchpress : ['olivebranchpr']
# blacklibrary : ['theblacklibrary']
# worldwrestlingentertainmentbooks : ['worldwrestlingentertainment']
# oakpress : ['akpress']
# bodleyhead : ['thebodleyhead']
# smatteringsbooks : ['smatteringbooks']
# johnmurraypublishers : ['johnmurraypublisher']
# oxforduniversitypress : ['samforduniversitypress', 'fordhamuniversitypress', 'stanforduniversitypress']
# sfischer : ['fischer']
# thefridayproject : ['thefridaypjoject']
# linlithglowpress : ['linlithgowpress']
# recordedbooks : ['colorecordedbooks']
# laureniumbadea : ['laureniubadea']
# pokrovpublications : ['oakgrovepublications']
# sealpress : ['sealpressca']
# audiobooks : ['bbcaudiobooks']
# kjcbooks : ['jcpbooks']
# deutschertaschenbuchverlag : ['fischertaschenbuchverlag']
# simonschusterchildrens : ['simonschusterchildrensbooks']
# amanapublications : ['vmapublications']
# nationalgeographickids : ['nationalgeographic']
# hachettechildrensbooks : ['hachettechildrens']
# forlagetoktoberas : ['forlagetokober']
# knightmedia : ['knightsofmedia']
# stanforduniversitypress : ['samforduniversitypress']
# universityofarizonapress : ['universityofiowapress']
# bigfinishaudiogobbc : ['bigfinishaudiogo']
# univofminnesotapress : ['universityofminnesotapress']
# universityofnorthcarolinapress : ['universityofsouthcarolinapress']
# querido : ['emquerido']
# fordhamuniversitypress : ['samforduniversitypress']
# dukeuniversitypress : ['dukeuniversitypressbooks']
# politypress : ['policypress']
# warner : ['warne']

# %%
# After reviewing several cutoff percentages, it was determined 0.86 was the best option, with a few cases that should be removed from the list:
remove_from_corrections = [['eiobooks', ['keibooks']],
                           ['torbooks', ['orbooks']],
                           ['duttonbooksforyoungreaders', ['crownbooksforyoungreaders']],
                           ['marinerbooks', ['warnerbooks']],
                           ['emuhousepublications', ['dreamhousepublication']],
                           ['zolabooks', ['zolandbooks']],
                           ['randomhouseaudiopublishinggroup',['randomhousepublishinggroup', 'therandomhousepublishinggroup']],
                           ['atheneumbooksforyoungreaders', ['hmhbooksforyoungreaders']],
                           ['knopfbooksforyoungreaders',['alfredaknopfbooksforyoungreaders', 'vikingbooksforyoungreaders']],
                           ['greenwillowbooks', ['greenhillbooks']],
                           ['owlbooks', ['howbooks']],
                           ['salmonpress', ['almondpress']],
                           ['oakpress', ['akpress']],
                           ['oxforduniversitypress', ['samforduniversitypress', 'fordhamuniversitypress', 'stanforduniversitypress']],
                           ['sfischer', ['fischer']], #Different standardization
                           ['recordedbooks', ['colorecordedbooks']],
                           ['pokrovpublications', ['oakgrovepublications']],
                           ['audiobooks', ['bbcaudiobooks']],
                           ['kjcbooks', ['jcpbooks']],
                           ['amanapublications', ['vmapublications']],
                           ['universityofarizonapress', ['universityofiowapress']],
                           ['universityofnorthcarolinapress', ['universityofsouthcarolinapress']],
                           ['querido', ['emquerido']],
                           ['fordhamuniversitypress', ['samforduniversitypress']],
                           ['nationalgeographickids', ['nationalgeographic']]
                           ]
for remove in remove_from_corrections:
    list_of_corrections.remove(remove)
# Adding the cases with "Different standardization"
list_of_corrections.append(['fischer', ['sfischer']])

# %%
# Standardize remaining list in publisher_clean column
for i in list_of_corrections:
    df_typos_removed.loc[df_typos_removed['publisher_clean'].isin(i[1]),'publisher_clean'] = i[0]

# %% [markdown]
# # Final dataset saved to CSV

# %%
df_final = df_typos_removed.copy()
df_final
# Out:
#                                                   title  series  \
# 0               Fantastic Beasts and Where to Find Them    True
# 1                                         Houdini Heart   False
# 2                   An Echo in the Bone (Outlander, #7)    True
# 3                                           Three Junes   False
# 4                   The Dark Tower (The Dark Tower, #7)    True
# ...                                                 ...     ...
# 9112            Edge of Passion (Stealth Guardians, #1)    True
# 9113  Tales from a Not-So-Popular Party Girl (Dork D...    True
# 9114                                            Bottoms   False
# 9115                                  The Wedding Dress   False
# 9116  The Immortal Hunter (Argeneau #11; Rogue Hunte...    True
#
#                     author       genre  date_published  \
# 0           Newt Scamander     Fantasy          2001.0
# 1            Ki Longfellow      Horror          2011.0
# 2           Diana Gabaldon  Historical          2010.0
# 3              Julia Glass     Fiction          2003.0
# 4             Stephen King     Fantasy          2006.0
# ...                    ...         ...             ...
# 9112           Tina Folsom     Fantasy          2012.0
# 9113  Rachel Renée Russell   Childrens          2010.0
# 9114       Tanja Kirschner     Unknown          2005.0
# 9115        Gary E. Parker     Unknown          2002.0
# 9116          Lynsay Sands     Romance          2009.0
#
#                    publisher     lang  rating_count  rate  award  \
# 0     Arthur A. Levine Books  English        372109  3.96      0
# 1                  Eio Books  English         10409  3.75      0
# 2                      Orion  English        133940  4.40      2
# 3                     Anchor  English         45789  3.56      1
# 4               Pocket Books  English        162749  4.23      1
# ...                      ...      ...           ...   ...    ...
# 9112                 Unknown  English          1011  4.01      0
# 9113                 Aladdin  English         54285  4.24      0
# 9114              NorthSouth  English            11  3.55      0
# 9115                  Victor  English            23  3.61      0
# 9116                    Avon  English         14498  4.22      0
#
#          publisher_clean
# 0     arthuralevinebooks
# 1               eiobooks
# 2                  orion
# 3                 anchor
# 4            pocketbooks
# ...                  ...
# 9112             unknown
# 9113             aladdin
# 9114          northsouth
# 9115              victor
# 9116                avon
#
# [9117 rows x 11 columns]

# %%
df_final.to_csv('Best_Book_21st_clean_dataset.csv', index = False)
